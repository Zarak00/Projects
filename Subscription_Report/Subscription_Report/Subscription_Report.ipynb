# %% [markdown]
# <a href="https://colab.research.google.com/github/Zarak00/Projects/blob/main/Subscription_Report/Subscription_Report/Subscription_Report.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import os
from google.colab import files

# %%
# Create a folder named "data"
folder_path = '/content/data'  # Specify the folder path
os.makedirs(folder_path, exist_ok=True)

# %%
# Upload the Excel file
uploaded = files.upload()

# Move the uploaded file to the "data" folder
file_name = list(uploaded.keys())[0]
file_path = os.path.join(folder_path, file_name)
os.rename(file_name, file_path)
# Out:
#      <input type="file" id="files-ee6b2f1b-a3cf-4326-b38c-061d88312f77" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ee6b2f1b-a3cf-4326-b38c-061d88312f77">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_excel(file_path, sheet_name="Base Plans")
df
# Out:
#        CUSTOMER_SUB_ID                                    CUSTOMER  \
# 0               141382                       Fair Wind Air Charter
# 1               167641        Hormel Foods Corporate Services, LLC
# 2               141382                       Fair Wind Air Charter
# 3               173159                   Philippine Airlines, Inc.
# 4               163635                West Coast Aviation Services
# ...                ...                                         ...
# 15890           206761                  Flying Horse Aviation, LLC
# 15891           170327                                   Legendair
# 15892           137859                             Avemex SA de CV
# 15893           142047            Air Products and Chemicals, Inc.
# 15894           133982  NATO Support and Procurement Agency (NSPA)
#
#                CUST_CTY CUST_ST CUST_COUNTRY  SUB_ID                SUB_NM  \
# 0                Stuart      FL          USA  145720   FAIWINADC01_ADC_DOM
# ...
